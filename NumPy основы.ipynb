# %%
import numpy as np
data = [1,2,3,4,5]
arr = np.array(data)
print(arr)
print(arr.shape)
print(arr.dtype)
print(arr.ndim)
# Out:
#   File "<ipython-input-18-c2775a6a3a59>", line 8
#     array = ([1,2,3], dtype = np.float)
#                             ^
# SyntaxError: invalid syntax

# %%
arr = np.array([1,2,3])
arr2 = np.array([0,0,0,5])
arr = np.concatenate((arr, arr2))
arr
# Out:
# array([1, 2, 3, 0, 0, 0, 5])
